# %%
# Execution Imports
from qiskit import Aer
from qiskit.aqua import QuantumInstance


#Operator Imports
from qiskit.aqua.operators import Z, X, I, StateFn, CircuitStateFn, SummedOp
from qiskit.aqua.operators.gradients import Gradient, NaturalGradient, QFI, Hessian

# Algorithm Imports
from qiskit.aqua.algorithms import VQE
from qiskit.aqua.components.optimizers import CG, ADAM
from qiskit.circuit.library import RealAmplitudes
from qiskit.aqua.operators import I, X, Z
from qiskit.circuit import QuantumCircuit, ParameterVector
from scipy.optimize import minimize

# Instantiate the system Hamiltonian
h2_hamiltonian = -1.05 * (I ^ I) + 0.39 * (I ^ Z) - 0.39 * (Z ^ I) - 0.01 * (Z ^ Z) + 0.18 * (X ^ X)

# This is the target energy
h2_energy = -1.85727503

# Define the Ansatz
ansatze = RealAmplitudes(2, reps = 3, entanglement = 'linear')
qc = QuantumCircuit(2)
qc.compose(ansatze, inplace = True)

# Define the expectation value corresponding to the energy
op = ~StateFn(h2_hamiltonian) @ StateFn(qc)


# grad = Gradient(grad_method='lin_comb')
grad = NaturalGradient(grad_method='lin_comb', qfi_method='lin_comb_full', regularization='ridge')
qi_sv = QuantumInstance(Aer.get_backend('statevector_simulator'),
                        shots=1,
                        seed_simulator=2,
                        seed_transpiler=2)

#Conjugate Gradient algorithm
optimizer = CG(maxiter=10)

vqe = VQE(h2_hamiltonian, qc, optimizer=optimizer, gradient=grad)

result = vqe.run(qi_sv)
print('Result:', result['optimal_value'], 'Reference:', h2_energy)
# Out:
# initial -1.3465145076962393
# gradient [ 0.407  0.201 -0.1    0.022  0.296 -0.326  0.194 -0.215]
# fubini study [[ 0.25  -0.     0.001  0.     0.047 -0.084  0.072 -0.159]
#  [-0.     0.25   0.    -0.091  0.229 -0.236 -0.026 -0.041]
#  [ 0.001  0.     0.25  -0.233 -0.089 -0.    -0.238 -0.189]
#  [ 0.    -0.091 -0.233  0.25   0.     0.085  0.231  0.19 ]
#  [ 0.047  0.229 -0.089  0.     0.25  -0.231  0.074 -0.   ]
#  [-0.084 -0.236 -0.     0.085 -0.231  0.25   0.     0.092]
#  [ 0.072 -0.026 -0.238  0.231  0.074 -0.     0.25   0.138]
#  [-0.159 -0.041 -0.189  0.19   0.     0.092  0.138  0.25 ]]
# gradient [-0.053 -0.091  0.337 -0.344  0.021  0.095 -0.274 -0.146]
# fubini study [[ 0.25   0.    -0.019 -0.     0.068 -0.054  0.161 -0.197]
#  [-0.     0.25  -0.     0.091  0.224 -0.244 -0.033  0.104]
#  [-0.019 -0.     0.25  -0.232  0.083 -0.    -0.2   -0.097]
#  [ 0.     0.091 -0.232  0.25   0.    -0.085  0.163  0.143]
#  [ 0.068  0.224  0.083 -0.     0.25  -0.235 -0.052 -0.   ]
#  [-0.054 -0.244  0.    -0.085 -0.235  0.25  -0.    -0.057]
#  [ 0.161 -0.033 -0.2    0.163 -0.052  0.     0.25  -0.056]
#  [-0.197  0.104 -0.097  0.143  0.    -0.057 -0.056  0.25 ]]
# gradient [-0.357 -0.056  0.013 -0.043  0.013  0.25  -0.192  0.321]
# fubini study [[ 0.25  -0.    -0.009 -0.    -0.034 -0.143  0.15  -0.232]
#  [ 0.     0.25  -0.     0.19   0.161 -0.205 -0.1    0.046]
#  [-0.009  0.     0.25  -0.163  0.189 -0.    -0.178 -0.074]
#  [-0.     0.19  -0.163  0.25   0.    -0.153  0.036  0.088]
#  [-0.034  0.161  0.189  0.     0.25  -0.116 -0.215  0.   ]
#  [-0.143 -0.205 -0.    -0.153 -0.116  0.25   0.     0.097]
#  [ 0.15  -0.1   -0.178  0.036 -0.215 -0.     0.25  -0.101]
#  [-0.232  0.046 -0.074  0.088 -0.     0.097 -0.101  0.25 ]]
# gradient [-0.21  -0.073  0.186 -0.185  0.025  0.146 -0.242  0.101]
# fubini study [[ 0.25   0.    -0.014 -0.     0.019 -0.099  0.16  -0.22 ]
#  [-0.     0.25   0.     0.144  0.204 -0.229 -0.065  0.081]
#  [-0.014  0.     0.25  -0.204  0.142 -0.    -0.19  -0.074]
#  [-0.     0.144 -0.204  0.25  -0.    -0.127  0.111  0.117]
#  [ 0.019  0.204  0.142 -0.     0.25  -0.198 -0.145  0.   ]
#  [-0.099 -0.229  0.    -0.127 -0.198  0.25  -0.     0.015]
#  [ 0.16  -0.065 -0.19   0.111 -0.145 -0.     0.25  -0.099]
#  [-0.22   0.081 -0.074  0.117  0.     0.015 -0.099  0.25 ]]
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-596c0c8f214a>", line 45, in <module>
#     result = vqe.run(qi_sv)
#   File "/Users/ouf/Documents/GitHub/qiskit-aqua/qiskit/aqua/algorithms/quantum_algorithm.py", line 71, in run
#     return self._run()
#   File "/Users/ouf/Documents/GitHub/qiskit-aqua/qiskit/aqua/algorithms/minimum_eigen_solvers/vqe.py", line 433, in _run
#     optimizer=self.optimizer)
#   File "/Users/ouf/Documents/GitHub/qiskit-aqua/qiskit/aqua/algorithms/vq_algorithm.py", line 213, in find_minimum
#     gradient_function=gradient_fn)
#   File "/Users/ouf/Documents/GitHub/qiskit-aqua/qiskit/aqua/components/optimizers/cg.py", line 83, in optimize
#     tol=self._tol, method="CG", options=self._options)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 602, in minimize
#     return _minimize_cg(fun, x0, args, jac, callback, **options)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 1363, in _minimize_cg
#     extra_condition=descent_condition)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 845, in _line_search_wolfe12
#     **kwargs)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/scipy/optimize/linesearch.py", line 101, in line_search_wolfe1
#     c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/scipy/optimize/linesearch.py", line 176, in scalar_search_wolfe1
#     derphi1 = derphi(stp)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/scipy/optimize/linesearch.py", line 90, in derphi
#     gval[0] = fprime(xk + s*pk, *newargs)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 327, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/Users/ouf/Documents/GitHub/qiskit-aqua/qiskit/aqua/operators/gradients/derivative_base.py", line 110, in gradient_fn
#     converter = CircuitSampler(backend=backend).convert(converter)
#   File "/Users/ouf/Documents/GitHub/qiskit-aqua/qiskit/aqua/operators/converters/circuit_sampler.py", line 212, in convert
#     param_bindings=p_b)
#   File "/Users/ouf/Documents/GitHub/qiskit-aqua/qiskit/aqua/operators/converters/circuit_sampler.py", line 273, in sample_circuits
#     self._transpiled_circ_cache = self.quantum_instance.transpile(circuits)
#   File "/Users/ouf/Documents/GitHub/qiskit-aqua/qiskit/aqua/quantum_instance.py", line 260, in transpile
#     **self._compile_config)
#   File "/Users/ouf/Documents/GitHub/qiskit-terra/qiskit/compiler/transpile.py", line 242, in transpile
#     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#   File "/Users/ouf/Documents/GitHub/qiskit-terra/qiskit/tools/parallel.py", line 151, in parallel_map
#     result = task(value, *task_args, **task_kwargs)
#   File "/Users/ouf/Documents/GitHub/qiskit-terra/qiskit/compiler/transpile.py", line 326, in _transpile_circuit
#     output_name=transpile_config['output_name'])
#   File "/Users/ouf/Documents/GitHub/qiskit-terra/qiskit/transpiler/passmanager.py", line 209, in run
#     return self._run_single_circuit(circuits, output_name, callback)
#   File "/Users/ouf/Documents/GitHub/qiskit-terra/qiskit/transpiler/passmanager.py", line 270, in _run_single_circuit
#     result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#   File "/Users/ouf/Documents/GitHub/qiskit-terra/qiskit/transpiler/runningpassmanager.py", line 113, in run
#     dag = self._do_pass(pass_, dag, passset.options)
#   File "/Users/ouf/Documents/GitHub/qiskit-terra/qiskit/transpiler/runningpassmanager.py", line 144, in _do_pass
#     dag = self._run_this_pass(pass_, dag)
#   File "/Users/ouf/Documents/GitHub/qiskit-terra/qiskit/transpiler/runningpassmanager.py", line 156, in _run_this_pass
#     new_dag = pass_.run(dag)
#   File "/Users/ouf/Documents/GitHub/qiskit-terra/qiskit/transpiler/passes/basis/basis_translator.py", line 151, in run
#     bound_target_dag = circuit_to_dag(target_circuit)
#   File "/Users/ouf/Documents/GitHub/qiskit-terra/qiskit/converters/circuit_to_dag.py", line 49, in circuit_to_dag
#     dagcircuit.calibrations = circuit.calibrations
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/ouf/anaconda3/envs/QiskitTesting/lib/python3.7/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
