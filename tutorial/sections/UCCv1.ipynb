# %%
import numpy as np
import qutip as qu

Sp = qu.sigmap()
Sm = qu.sigmam()
ID = qu.identity(2)

JW = True
N_qubit= 8
N_AO   = 4
N_occ  = 2
# spin convenction:  alpha     , beta 
GS_HF = qu.tensor(qu.basis(2,1),qu.basis(2,1),\
                  qu.basis(2,0),qu.basis(2,0),\
                  qu.basis(2,0),qu.basis(2,0),\
                  qu.basis(2,0),qu.basis(2,0)).unit()

E_HF = -1.126108
ENN =   0.755967

#---------------------
if JW == True:
    Sz = qu.sigmaz()
else:
    Sz = qu.identity(2)
#---------------------    

ID8 = qu.tensor(qu.identity(2),qu.identity(2),qu.identity(2),qu.identity(2), \
                    qu.identity(2),qu.identity(2),qu.identity(2),qu.identity(2))


val = qu.expect(ID8, GS_HF)
print(val)
# Out:
# 1.0

# %% [markdown]
# Gaussian Code results for the AO basis
#
# 30 Jun 2017

# %%
coef        = np.zeros((N_AO+1,N_AO+1))
coef_spinor = np.zeros((N_AO  ,N_qubit))
                 
#  [AO][MO]
coef[1][1]=0.33347   
coef[2][1]=0.26168
coef[3][1]=0.33347
coef[4][1]=0.26168
coef[1][2]=0.11471
coef[2][2]=1.82179
coef[3][2]=-0.11471
coef[4][2]=-1.82179
coef[1][3]=0.74836
coef[2][3]=-0.68371
coef[3][3]=0.74836
coef[4][3]=-0.68371
coef[1][4]=-1.15811
coef[2][4]=1.38263
coef[3][4]=1.15811
coef[4][4]=-1.38263

for i in range(1,N_AO+1):
    # i=1,..,N_qubit_R
    for j in range(1,N_AO+1):
        coef_spinor[i-1][2*j-2]     = coef[i][j]
        coef_spinor[i-1][2*j-1]     = coef[i][j]
        
#print coef_spinor

# %% [markdown]
# Two Electron Integrals # Remember that 0 and 1 are identical (in the RHF)

# %%
gint = np.zeros((N_AO+1,N_AO+1,N_AO+1,N_AO+1))

gint[1][1][1][1]= 1.07656613
gint[1][1][1][2]= 0.5784703
gint[1][1][1][3]= 0.44741177
gint[1][1][1][4]= 0.45354346
gint[1][1][2][1]= 0.5784703
gint[1][1][2][2]= 0.58739583
gint[1][1][2][3]= 0.36431198
gint[1][1][2][4]= 0.4905666
gint[1][1][3][1]= 0.44741177
gint[1][1][3][2]= 0.36431198
gint[1][1][3][3]= 0.6881531
gint[1][1][3][4]= 0.42033145
gint[1][1][4][1]= 0.45354346
gint[1][1][4][2]= 0.4905666
gint[1][1][4][3]= 0.42033145
gint[1][1][4][4]= 0.50617715
gint[1][2][1][1]= 0.5784703
gint[1][2][1][2]= 0.32942312
gint[1][2][1][3]= 0.25347214
gint[1][2][1][4]= 0.25907321
gint[1][2][2][1]= 0.32942312
gint[1][2][2][2]= 0.36130377
gint[1][2][2][3]= 0.21965688
gint[1][2][2][4]= 0.30321243
gint[1][2][3][1]= 0.25347214
gint[1][2][3][2]= 0.21965688
gint[1][2][3][3]= 0.42033145
gint[1][2][3][4]= 0.25764144
gint[1][2][4][1]= 0.25907321
gint[1][2][4][2]= 0.30321243
gint[1][2][4][3]= 0.25764144
gint[1][2][4][4]= 0.31691708
gint[1][3][1][1]= 0.44741177
gint[1][3][1][2]= 0.25347214
gint[1][3][1][3]= 0.23525747
gint[4][1][3][2]= 0.18521249
gint[4][1][3][3]= 0.36431198
gint[4][1][3][4]= 0.21965688
gint[4][1][4][1]= 0.20704132
gint[4][1][4][2]= 0.24555854
gint[4][1][4][3]= 0.21965688
gint[4][1][4][4]= 0.26224343
gint[4][2][1][1]= 0.4905666
gint[4][2][1][2]= 0.30321243
gint[4][2][1][3]= 0.2476473
gint[4][2][1][4]= 0.24555854
gint[4][2][2][1]= 0.30321243
gint[4][2][2][2]= 0.38445364
gint[4][2][2][3]= 0.24555854
gint[4][2][2][4]= 0.34172851
gint[4][2][3][1]= 0.2476473
gint[4][2][3][2]= 0.24555854
gint[4][2][3][3]= 0.4905666
gint[4][2][3][4]= 0.30321243
gint[4][2][4][1]= 0.24555854
gint[4][2][4][2]= 0.34172851
gint[4][2][4][3]= 0.30321243
gint[4][2][4][4]= 0.38445364
gint[4][3][1][1]= 0.42033145
gint[4][3][1][2]= 0.25764144
gint[4][3][1][3]= 0.25347214
gint[4][3][1][4]= 0.21965688
gint[4][3][2][1]= 0.25764144
gint[4][3][2][2]= 0.31691708
gint[4][3][2][3]= 0.25907321
gint[4][3][2][4]= 0.30321243
gint[4][3][3][1]= 0.25347214
gint[4][3][3][2]= 0.25907321
gint[4][3][3][3]= 0.5784703
gint[4][3][3][4]= 0.32942312
gint[4][3][4][1]= 0.21965688
gint[4][3][4][2]= 0.30321243
gint[4][3][4][3]= 0.32942312
gint[4][3][4][4]= 0.36130377
gint[4][4][1][1]= 0.50617715
gint[4][4][1][2]= 0.31691708
gint[4][4][1][3]= 0.27465884
gint[4][4][1][4]= 0.26224343
gint[4][4][2][1]= 0.31691708
gint[4][4][2][2]= 0.41390204
gint[4][4][2][3]= 0.28552445
gint[4][4][2][4]= 0.38445364
gint[4][4][3][1]= 0.27465884
gint[4][4][3][2]= 0.28552445
gint[4][4][3][3]= 0.58739583
gint[4][4][3][4]= 0.36130377
gint[4][4][4][1]= 0.26224343
gint[4][4][4][2]= 0.38445364
gint[4][4][4][3]= 0.36130377
gint[4][4][4][4]= 0.45315033

# %%
rsgtu = np.zeros((N_qubit+1,N_qubit+1,N_qubit+1,N_qubit+1))

#molecular orbitals

for r in range(N_qubit):
    # r=0,...,N_qubit-1
    for s in range(N_qubit):
        for t in range(N_qubit):
            for u in range(N_qubit):
                #atomic orbitals
                
                for nu in range(1,N_AO+1):     
                    for mu in range(1,N_AO+1):               
                        for lamda in range(1,N_AO+1):                         
                            for sigma in range(1,N_AO+1):
                                
                                rsgtu[r][s][t][u] += coef_spinor[mu-1][r]    *\
                                                     coef_spinor[nu-1][s]    *\
                                                     coef_spinor[lamda-1][t] *\
                                                     coef_spinor[sigma-1][u] *\
                                                     gint[mu][nu][lamda][sigma]

                                
                # print("rsgtu["+str(r)+"]["+str(s)+"]["+str(t)+"]["+str(u)+"]="+str(rsgtu[r][s][t][u]))

# %%
print(rsgtu[0][0][0][0])
print(rsgtu[3][3][3][3])
# Out:
# 0.665551170816
# 0.383768923391

# %% [markdown]
# Two electron integrals in Molecular Basis

# %%
# rsgtu in physics notation (McWeeny in in physic notation (eq.9.2.10 and eq. 3.2.6)) 
# while Gaussian is in the chemistry notation
# add also integral over spin!
#  the even orbitals are alpha
#  the odd orbitals are beta
rsgtu_ph = np.zeros((N_qubit,N_qubit,N_qubit,N_qubit))

for r in range(N_qubit):
    if (r & 1) == 0:
        a=-1
    else:
        a=1
    # r=0,..,N_qubit
    for s in range(N_qubit):
        if (s & 1) == 0:
            b=-1
        else:
            b=1
        for t in range(N_qubit):
            if (t & 1) == 0:
                c=-1
            else:
                c=1
            for u in range(N_qubit):
                if (u & 1) == 0:
                    d=-1
                else:
                    d=1
                    
                if (a*b>0 and c*d>0):
                    fact=1.
                else:
                    fact=0.
                
                rsgtu_ph[r][t][s][u] = fact * rsgtu[r][s][t][u].copy()

# %%
# do the one body term as in McWeeny Eq. (9.2.12)
# H_core as in Szabo Eq. (3.153). Taken from the Gaussian output (Plotted with szabo_RHF.F90)
H_core = np.zeros((N_AO+1,N_AO+1))
rFs    = np.zeros((N_qubit  ,N_qubit))

#   [AO][AO]
H_core[1][1]=-0.9962602
H_core[1][2]=-0.9386350  
H_core[1][3]=-0.8721280  
H_core[1][4]=-0.8102180
H_core[2][1]=-0.9386350  
H_core[2][2]=-0.9371630  
H_core[2][3]=-0.8102180  
H_core[2][4]=-0.8725020
H_core[3][1]=-0.8721280  
H_core[3][2]=-0.8102180  
H_core[3][3]=-0.9962602  
H_core[3][4]=-0.9386350
H_core[4][1]=-0.8102180  
H_core[4][2]=-0.8725020 
H_core[4][3]=-0.9386350  
H_core[4][4]=-0.9371630

H_core_MO = np.zeros((N_qubit,N_qubit))
for r in range(N_qubit):
    #r = 0,...,N_qubits-1
    for s in range(N_qubit):
        for mu in range(1,N_AO+1):
            for nu in range(1,N_AO+1):
                #print(r,s,mu,nu)
                H_core_MO[r][s] += coef_spinor[mu-1][r]*coef_spinor[nu-1][s] * H_core[mu][nu]

#print H_core_MO                

#print(np.round(H_core_MO,N_qubits))
#with spin information!

rFs = np.zeros((N_qubit,N_qubit))
for r in range(N_qubit):
    if (r & 1) == 0:
        a=-1
    else:
        a=1
    for s in range(N_qubit):
        if (s & 1) == 0:
            b=-1
        else:
            b=1
            
        if a*b>0:
            fact=1.
        else:
            fact=0.
            
        rFs[r][s] = fact * H_core_MO[r][s]
        
        for i in range (N_occ):
            # i=1,...,N_occ
            #spin information already in rsgtu_ph
            rFs[r][s] += rsgtu_ph[r][i][s][i] - rsgtu_ph[r][i][i][s]

#print(np.round(rFs,N_qubit))

# %%
import qutip as qu

################################################################################
# SORTING FUNCTION
# seq : the sorted array
# swap_counter : the number of swaps needed for sorting

def sort(seq):
    # print(seq)
    swap_counter = 0
    changed = True
    while changed:
        changed = False
        for i in range(len(seq) - 1):
            if seq[i] > seq[i + 1]:
                swap_counter += 1
                seq[i], seq[i + 1] = seq[i + 1], seq[i]
                changed = True
                # print(seq)
    return seq, swap_counter


################################################################################
# MAPPING FOR THE NORMAL ORDERING
#
# e.g. for 2 occupied orbitals
#
# OCCUPIED         | VIRTUAL
# a[0]    a[1]     | a[2]    a[3]    ...
# -1      -2       | 3       4
#                  |
# adag[0] adag[1]  | adag[2] adag[3] ...
# 1       2        | -3      -4
#
# In the case adag[0]*a[1] -> 1,-2 (sort)  -> (-1) -2,1     -> -a[1]*adag[0]
# it is right adag[0]*a[1] -> b[0]*bdag[1] -> -bdag[1]*b[0] -> -a[1]*adag[0]
#
################################################################################

def normal_order(N_qubits, N_occupied, array_to_be_ordered, array_mapping, printout = False, JW = True):

    if printout == True:

        print("Normal Ordering Starting")
        print("You are printing variables for steps of the normal ordering")
        print("Jordan - Wigner transformation is : ", JW)
################################################################################
## FUNCTION Arguments
#
# N_qubits : number of qubits
# N_occupied : number of occupied orbitals
# array_to_be_ordered : indices of the terms
# array_mapping : type of each operator (create or destroy operators)
# print : print the initial and the normal ordered terms (default: False)
#
# e.g. adag[0]*a[1]*adag[1]*a[3]
# array_to_be_ordered : [0,1,1,3]
# array_mapping : [adag, a, adag, a]
#
################################################################################

#   printout the starting term
    if printout:

        a_print = []
        adag_print = []

        for i in range(N_qubits):
            a_print.append("a"+str(i))
            adag_print.append("adag"+str(i))

        print_in = " "
        for i in range(len(array_to_be_ordered)):
            print_in += array_mapping[i]+str(array_to_be_ordered[i])+str(" ")
        print("Starting term :",print_in)

    #mapping to numbers for sorting
    a_enum = []
    adag_enum = []

    for i in range(N_qubits):

        if i < N_occupied:
            a_enum.append(-(i+1))
            adag_enum.append(i+1)

        else:
            a_enum.append(i+1)
            adag_enum.append(-(i+1))

    #print(a_enum)
    #print(adag_enum)

#   make the array to be sorted
    array_to_be_sorted = []

    for i in range(len(array_to_be_ordered)):

        if array_mapping[i] == "adag":
            array_to_be_sorted.append(adag_enum[array_to_be_ordered[i]])

        elif array_mapping[i] == "a":
            array_to_be_sorted.append(a_enum[array_to_be_ordered[i]])

# print(array_to_be_sorted)

#   sorting and counting the number of swaps
    sign = (-1)**sort(array_to_be_sorted)[1]
    array_sorted = sort(array_to_be_sorted)[0]

    # print(sign, array_sorted)

    #print the final term
    if printout == True:

        print_out = ""
        for i in array_sorted:
            if i in a_enum:
                print_out+= "a"+str(a_enum.index(i))+" "

            elif i in adag_enum:
                print_out += "adag"+str(adag_enum.index(i))+" "

        print("Final term : ", str(sign), print_out)

    #creating a and adag operators
    a_oper = []
    adag_oper = []

    for i in range(N_qubits):

        if i == 0:
            operator = qu.destroy(2)

        else:
            operator = qu.identity(2)

        for j in range(1,N_qubits):

            if j < i:
                operator = qu.tensor(operator,qu.identity(2))

            elif i == j:
                operator = qu.tensor(operator,qu.destroy(2))

            else:
                if JW == True:
                    operator = qu.tensor(operator,qu.sigmaz())
                else:
                    operator = qu.tensor(operator, qu.identity(2))

        a_oper.append(operator)
        adag_oper.append(operator.dag())

    #creating the ordered array operator
    sorted_operator = 1

    for i in array_sorted:
        if i in a_enum:
            sorted_operator *= a_oper[a_enum.index(i)]

        elif i in adag_enum:
            sorted_operator *= adag_oper[adag_enum.index(i)]

    sorted_operator = sign*sorted_operator

    return sorted_operator

# %%
#from Integral_Coefficients_RHF_new import *
#from Normal_ordering_RHF import *
import qutip as qu

##TODO : Implement the particle/hole Hamiltonian

Hamiltonian_RHF = 0

#one-body terms term
for r in range(N_qubit): #[0,1,2,3]:
    for s in range(N_qubit): #[0,1,2,3]:
        Hamiltonian_RHF += rFs[r][s] * normal_order(N_qubit,N_occ,[r,s],['adag','a'])

print("single body terms - spin ab - generated")

# #two-body terms
for r in range(N_qubit): #[0,1, 2, 3]:
    for s in range(N_qubit): #[0,1, 2, 3]:
        for t in range(N_qubit): #[0,1, 2, 3]:
            for u in range(N_qubit): #[0,1, 2, 3]:
                Hamiltonian_RHF += 0.5 * rsgtu_ph[r][s][t][u] * normal_order(N_qubit,N_occ,[r,s,u,t],['adag','adag','a','a'])

print("two body terms - spin ab - generated")

#print(Hamiltonian.eigenstates()[0])
# print(normal_order_2(0, 3))

print(Hamiltonian_RHF.eigenstates()[0])

print(qu.expect(Hamiltonian_RHF,GS_HF))
# Out:
# single body terms - spin ab - generated
# two body terms - spin ab - generated
# [ -0.02403329   0.22397258   0.22397258   0.39401484   0.39401484
#    0.39401484   0.55114759   0.58110861   0.58110861   0.66871669
#    0.66871669   0.71954101   0.71954101   0.82455714   0.82455714
#    0.82455714   0.83494349   0.98393859   0.98393859   0.98393859
#    0.98393859   1.01772688   1.09850314   1.09850314   1.14053192
#    1.24497791   1.24497791   1.28986403   1.28986403   1.28986403
#    1.29020097   1.29020097   1.35364163   1.39998321   1.39998321
#    1.39998321   1.42481717   1.42481717   1.43808821   1.47312486
#    1.47312486   1.47312486   1.58130994   1.58130994   1.58130994
#    1.58130994   1.60639219   1.60639219   1.61413161   1.61413161
#    1.61413161   1.64927199   1.64927199   1.70386603   1.70386603
#    1.77412499   1.78863491   1.78863491   1.82241884   1.88207548
#    1.92004659   1.93716143   1.94451989   1.94451989   1.96398788
# ...

# %%
from scipy.optimize import minimize

# %%
a = [qu.tensor(Sp, Sz, Sz, Sz, Sz, Sz, Sz, Sz), \
     qu.tensor(ID, Sp, Sz, Sz, Sz, Sz, Sz, Sz), \
     qu.tensor(ID, ID, Sp, Sz, Sz, Sz, Sz, Sz), \
     qu.tensor(ID, ID, ID, Sp, Sz, Sz, Sz, Sz), \
     qu.tensor(ID, ID, ID, ID, Sp, Sz, Sz, Sz), \
     qu.tensor(ID, ID, ID, ID, ID, Sp, Sz, Sz), \
     qu.tensor(ID, ID, ID, ID, ID, ID, Sp, Sz), \
     qu.tensor(ID, ID, ID, ID, ID, ID, ID, Sp)]

adag = [qu.tensor(Sm, Sz, Sz, Sz, Sz, Sz, Sz, Sz), \
     qu.tensor(ID, Sm, Sz, Sz, Sz, Sz, Sz, Sz), \
     qu.tensor(ID, ID, Sm, Sz, Sz, Sz, Sz, Sz), \
     qu.tensor(ID, ID, ID, Sm, Sz, Sz, Sz, Sz), \
     qu.tensor(ID, ID, ID, ID, Sm, Sz, Sz, Sz), \
     qu.tensor(ID, ID, ID, ID, ID, Sm, Sz, Sz), \
     qu.tensor(ID, ID, ID, ID, ID, ID, Sm, Sz), \
     qu.tensor(ID, ID, ID, ID, ID, ID, ID, Sm)]

# define p with suited size = number of parameters (see function UCC_ansatzes)
N_parameters=14 +1
p = np.zeros((N_parameters))

def UCC_ansatzes(p, CCSD):
    
#    0 1 || 2 3 | 4 5 | 6 7 
    
    T1 =  p[0]*adag[2]*a[0] \
        + p[1]*adag[4]*a[0] \
        + p[2]*adag[6]*a[0] \
        + p[3]*adag[3]*a[1] \
        + p[4]*adag[5]*a[1] \
        + p[5]*adag[7]*a[1]

    T1dag = T1.dag()
    
    T2 = (1/4.) * (p[6] * adag[3]*adag[2]*a[1]*a[0]
            +p[7] * adag[5]*adag[2]*a[1]*a[0]\
            +p[8] * adag[7]*adag[2]*a[1]*a[0]\
            +p[9] * adag[3]*adag[4]*a[1]*a[0]\
            +p[10]* adag[5]*adag[4]*a[1]*a[0]\
            +p[11]* adag[7]*adag[4]*a[1]*a[0]\
            +p[12]* adag[3]*adag[6]*a[1]*a[0]\
            +p[13]* adag[5]*adag[6]*a[1]*a[0]\
            +p[14]* adag[7]*adag[6]*a[1]*a[0])
                    
    T2dag = T2.dag()

    CCS = True

    if CCSD == True:
        CCS = False

    if CCS == True:
        T    = T1
        Tdag = T1dag 

    if CCSD == True:
        T    = T1 + T2
        Tdag = T1dag + T2dag
    
    Tdif = T - Tdag
    
    #remove unit()
    return (Tdif.expm()*GS_HF) #.unit()

def analytic_min(p):
    
    #remove unit()
    psi_UCC = UCC_ansatzes(p, CCSD = True) #.unit()
    
    # do not renormalize! remove unit()
    # val = qu.expect(Hamiltonian_RHF, psi_UCC.unit()) #/float(qu.expect(ID4, psi_UCC))
    val = qu.expect(Hamiltonian_RHF, psi_UCC)
    
    return val.real

# initialize p 
for r in range(N_parameters):
    p[r]= 0.1

res = minimize(analytic_min, p, method='BFGS', tol=1e-5)

print(res)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-270e9d988bda> in <module>()
#      60     p[r]= 0.1
#      61
# ---> 62 res = minimize(analytic_min, p, method='BFGS', tol=1e-5)
#      63
#      64 print(res)
#
# /Users/amezzac/anaconda/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     442         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     443     elif meth == 'bfgs':
# --> 444         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     445     elif meth == 'newton-cg':
#     446         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ...

# %%
print(res.x)

# %%
rFs_new = np.zeros((4,4))
rsgtu_new = np.zeros((4,4,4,4))
rsgtu_ph_new = np.zeros((4,4,4,4))

i=0
for r in [0,2,4,6]:
    j=0
    for s in [0,2,4,6]:
        
        rFs_new[i][j] = rFs[r][s].copy()
        k=0
        for t in [0,2,4,6]:
            l=0
            for u in [0,2,4,6]:
                
                rsgtu_new[i][j][k][l] = rsgtu[r][s][t][u].copy()
                rsgtu_ph_new[i][j][k][l] = rsgtu_ph[r][s][t][u].copy()
                
                l += 1
            k += 1
        j += 1
    i += 1

# %%
print(rFs_new)
# Out:
# [[ -6.08262156e-01   9.10729825e-16  -6.49386625e-06   8.77770079e-16]
#  [ -1.47451495e-16   2.49062091e-01   9.02056208e-16  -1.39083397e-05]
#  [ -6.49386625e-06   1.80411242e-16   7.55661364e-01  -5.55111512e-16]
#  [  9.36750677e-17  -1.39083397e-05  -8.22258928e-16   1.46029543e+00]]

# %%
# Checking the version of PYTHON; we only support 3 at the moment
import sys
if sys.version_info < (3,0):
    raise Exception("Please use Python version 3 or greater.")
    
    
# useful additional packages 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from scipy import linalg as la


import sys
sys.path.append("../../..")
# importing the QISKit

from qiskit import QuantumCircuit, QuantumProgram
import Qconfig
import math

# import basic plot tools
from qiskit.basicplotter import plot_histogram

# import optimization tools
from tools.optimizationtools import trial_circuit_ryrz,trial_circuit_ry, SPSA_optimization, SPSA_calibration
from tools.optimizationtools import Energy_Estimate, Measure_pauli_z, Hamiltonian_from_file, make_Hamiltonian
from functools import partial
from tools.pauli import Pauli, label_to_pauli
from tools.fermion_to_qubit_tools import fermionic_maps, two_qubit_reduction
