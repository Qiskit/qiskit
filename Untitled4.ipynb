# %%
import qiskit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-578b7f7e9727> in <module>
# ----> 1 import qiskit
#
# ~\qiskit-terra\qiskit\__init__.py in <module>
#      24
#      25 # The main qiskit operators
# ---> 26 from qiskit.circuit import ClassicalRegister
#      27 from qiskit.circuit import QuantumRegister
#      28 from qiskit.circuit import AncillaRegister
#
# ~\qiskit-terra\qiskit\circuit\__init__.py in <module>
#     229 from .parameterexpression import ParameterExpression
#     230 from .equivalence import EquivalenceLibrary
# --> 231 from .classicalfunction.types import Int1, Int2
#     232 from .classicalfunction import classical_function, BooleanExpression
#
# ~\qiskit-terra\qiskit\circuit\classicalfunction\__init__.py in <module>
#      96
#      97 """
# ---> 98 from .classicalfunction import ClassicalFunction
#      99 from .exceptions import (
# ...
