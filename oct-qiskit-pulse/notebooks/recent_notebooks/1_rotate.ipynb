# %% [markdown]
# # Calculation of control fields for QFT gate on two qubits using L-BFGS-B algorithm

# %% [markdown]
# Alexander Pitchford (agp1@aber.ac.uk)

# %%
cd /Users/benrosand/oct-qiskit-pulse
# Out:
# /Users/benrosand/oct-qiskit-pulse

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
from qutip import Qobj, identity, sigmax, sigmay, sigmaz, tensor, hadamard_transform, basis, cnot
from qutip.qip.algorithms import qft
import qutip.logging_utils as logging
logger = logging.get_logger()
#Set this to None or logging.WARN for 'quiet' execution
log_level = logging.INFO
#QuTiP control modules
import qutip.control.pulseoptim as cpo
import qutip.control.pulsegen as pulsegen
from src.qutip_helper import convert_qutip_ham
from src.helper import *
from qiskit import IBMQ
from qutip.qip.device import Processor
from qiskit.pulse import Play, SamplePulse

from qiskit.providers.aer.pulse.system_models.hamiltonian_model import HamiltonianModel
from src.three_restructure import *
example_name = 'QFT'

# %% [markdown]
# ### Defining the physics

# %% [markdown]
# Note here that there are two controls acting on each qubit.

# %%
# subsystem_list=[0,1]
subsystem_list=[0]
IBMQ.load_account()

# provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
provider = IBMQ.get_provider(hub='ibm-q-internal', group='deployed', project='default')
backend = provider.get_backend('ibmq_valencia')
backend.configuration().hamiltonian['vars']
# backend.configuration().hamiltonian['vars']['delta0'] = -3.3

omegad_mult = True
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
config = backend.configuration()
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
config.backend_name
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 'ibmq_valencia'

# %% [markdown]
# \begin{align} \mathcal{H}/\hbar = & \sum_{i=0}^{4}\left(\frac{\omega_{q,i}}{2}(\mathbb{I}-\sigma_i^{z})+\frac{\Delta_{i}}{2}(O_i^2-O_i)+\Omega_{d,i}D_i(t)\sigma_i^{X}\right) \\ & + J_{1,2}(\sigma_{1}^{+}\sigma_{2}^{-}+\sigma_{1}^{-}\sigma_{2}^{+}) + J_{3,4}(\sigma_{3}^{+}\sigma_{4}^{-}+\sigma_{3}^{-}\sigma_{4}^{+}) + J_{0,1}(\sigma_{0}^{+}\sigma_{1}^{-}+\sigma_{0}^{-}\sigma_{1}^{+}) + J_{2,3}(\sigma_{2}^{+}\sigma_{3}^{-}+\sigma_{2}^{-}\sigma_{3}^{+}) \\ & + \Omega_{d,0}(U_{0}^{(0,1)}(t))\sigma_{0}^{X} + \Omega_{d,1}(U_{1}^{(1,0)}(t)+U_{2}^{(1,2)}(t))\sigma_{1}^{X} \\ & + \Omega_{d,2}(U_{3}^{(2,1)}(t)+U_{4}^{(2,3)}(t))\sigma_{2}^{X} + \Omega_{d,3}(U_{6}^{(3,4)}(t)+U_{5}^{(3,2)}(t))\sigma_{3}^{X} \\ & + \Omega_{d,4}(U_{7}^{(4,3)}(t))\sigma_{4}^{X} \\ \end{align}

# %%
zero_vars = ['wq0']

H_d, H_c = get_hamiltonians(config, subsystem_list, ['wq0'])

U_0 = identity(3)
U_targ = get_sigmax()
gate_type = 'XGate'

config = backend.configuration()
hamiltonian = config.hamiltonian
# backend.configuration().hamiltonian['vars']['omegad0'] = hamiltonian['vars']['omegad0'] * 2

# H_c.pop(1)
notes = ''
# notes += 'omegad0 * 2'
# notes = 'no y control'
# notes = 'def_x on q0'
# pulse type alternatives: RND|ZERO|LIN|SINE|SQUARE|SAW|TRIANGLE|
p_type = 'LIN'
DEROTATE = False

# notes += 'zeros: ' + str(zero_vars)

n_ctrls = len(H_c)
# ! Don't forget to try omegad0 * 2 or / 2
# Out:
# U0
# not using control channels, skippping...
# D0
# Double check that sigx2 and  sigy2 are right
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# For 2 level system
two_level=True
if two_level:
    notes += ', 2 levels'
    omegad0 = backend.configuration().hamiltonian['vars']['omegad0']
    omegad1 = backend.configuration().hamiltonian['vars']['omegad1']

    q1sigx = tensor(sigmax(), identity(2))
    q1sigy = tensor(sigmay(), identity(2))
    q0sigx = tensor(identity(2), sigmax())
    q0sigy = tensor(identity(2), sigmay())


    # q0sigy[]

    # H_c = [omegad0 * q0sigx, omegad0 * q0sigy, omegad1 * q1sigx, omegad1 * q1sigy]
    H_c = [omegad0 * sigmax(), omegad0 * sigmay()]
    # U_0 = tensor(identity(2), identity(2))
    U_0 = identity(2)
    H_d = U_0 * 0
    # U_targ = hadamard_transform(1)
    # U_targ = cnot()
    U_targ = sigmax()
    gate_type= 'XGate'
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
H_d
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0. 0.]
#  [0. 0.]]

# %% [markdown]
# Multiple total evolution times will be tried. Using this approach, the minimum evolution time required to achieve the target fidelity could be determined (iteratively).
#
# Note that the timeslot duration dt is fixed, and so the number of timeslots depends on the evo_time

# %%
# Duration of each timeslot
dt = backend.configuration().dt * 1e9
# dt = 0.02
# n_ts_00 = []#[16,32]
n_ts_0 = list(np.arange(64,160, 32))
n_ts_list = list(np.arange(160,1600,160))
n_ts_list = n_ts_0 + n_ts_list
# n_ts_list = [160]#, 480, 560,640]
evo_times = [dt * n for n in n_ts_list]
# List of evolution times to try
# evo_times = [1, 3, 6]
n_evo_times = len(evo_times)
evo_time = evo_times[0]
n_ts = int(float(evo_time) / dt)
#Empty list that will hold the results for each evolution time
# results = list()
n_ts_list
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [64, 96, 128, 160, 320, 480, 640, 800, 960, 1120, 1280, 1440]

# %% [markdown]
# ### Set the conditions which will cause the pulse optimisation to terminate

# %% [markdown]
# ### Set the initial pulse type

# %% [markdown]
# Here the linear initial pulse type is used, simply because it results in smooth final pulses

# %% [markdown]
# ### Give an extension for output files

# %%
#Set to None to suppress output files
# f_ext = "{}_n_ts{}_ptype{}.txt".format(example_name, n_ts, p_type)
f_ext = None
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
H_c[0]
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0.         0.49771143]
#  [0.49771143 0.        ]]

# %% [markdown]
# ### Create the optimiser objects

# %% [markdown]
# Here is the main difference between this and the Hadamard example. In this case we use a different pulseoptim function that just creates the objects that can be used to set the physics and configure the optimisation algorithm. This gives greater flexibility (shown here by seting different initial pulse parameters for each control) and is also more efficient when running multiple optimisations on the same system.

# %%
# Fidelity error target
fid_err_targ = 1e-30
# Maximum iterations for the optisation algorithm
max_iter = 2000
# Maximum (elapsed) time allowed in seconds
max_wall_time = 120
# Minimum gradient (sum of gradients squared)
# as this tends to 0 -> local minima has been found
min_grad = 1e-30
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# p_gen[0]
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
optim = cpo.create_pulse_optimizer(H_d, H_c, U_0, U_targ, n_ts, evo_time, 
                amp_lbound=-.7, amp_ubound=.7, 
                fid_err_targ=fid_err_targ, min_grad=min_grad, 
                max_iter=max_iter, max_wall_time=max_wall_time, 
                optim_method='fmin_l_bfgs_b',
                method_params={'max_metric_corr':20, 'accuracy_factor':1e8},
                dyn_type='UNIT', 
                fid_params={'phase_option':'PSU'},
                init_pulse_type=p_type, 
                log_level=log_level, gen_stats=True, alg='GRAPE')

# **** get handles to the other objects ****
optim.test_out_files = 0
dyn = optim.dynamics
dyn.test_out_files = 0
p_gen = optim.pulse_generator
results = run_optimizer(optim, dt, n_evo_times,dyn, p_type, n_ts, len(H_c), f_ext, evo_time, evo_times, p_gen)
# Out:
#  control amplitude updates: 6
# Mean number of updates per iteration: 1.0
# Number of timeslot values changed: 768
# Mean number of timeslot changes per update: 128.0
# Number of amplitude values changed: 1536
# Mean number of amplitude changes per update: 256.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 1.35214024e-05-1.27818983e-04j -2.75855498e-05-9.99999991e-01j]
#  [ 2.75855498e-05-9.99999991e-01j  1.35214024e-05+1.27818983e-04j]]
#
# ********* Summary *****************
# Final fidelity error 8.640765436496167e-09
# Final gradient normal 0.0001391632435604798
# Terminated due to function converged
# Number of iterations 6
# Completed in 0:00:00.300368 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=35.55555555555556
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:00.517733
# Wall time computing Hamiltonians: 0:00:00.013036 (2.52%)
# Wall time computing propagators: 0:00:00.412495 (79.67%)
# Wall time computing forward propagation: 0:00:00.002189 (0.42%)
# Wall time computing onward propagation: 0:00:00.001628 (0.31%)
# Wall time computing gradient: 0:00:00.026142 (5.05%)
#
# **** Iterations and function calls ****
# Number of iterations: 6
# Number of fidelity function calls: 7
# Number of times fidelity is computed: 7
# Number of gradient function calls: 7
# Number of times gradients are computed: 7
# Number of times timeslot evolution is recomputed: 7
#
# **** Control amplitudes ****
# Number of control amplitude updates: 6
# Mean number of updates per iteration: 1.0
# Number of timeslot values changed: 960
# Mean number of timeslot changes per update: 160.0
# Number of amplitude values changed: 1920
# Mean number of amplitude changes per update: 320.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[-5.75549833e-08+5.83673987e-07j -2.67724207e-07+1.00000000e+00j]
#  [ 2.67724207e-07+1.00000000e+00j -5.75549815e-08-5.83673986e-07j]]
#
# ********* Summary *****************
# Final fidelity error 2.3425705819590803e-13
# Final gradient normal 6.630187136502188e-07
# Terminated due to function converged
# Number of iterations 6
# Completed in 0:00:00.517733 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=71.11111111111111
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:01.129080
# Wall time computing Hamiltonians: 0:00:00.032982 (2.92%)
# Wall time computing propagators: 0:00:00.881329 (78.06%)
# Wall time computing forward propagation: 0:00:00.004433 (0.39%)
# Wall time computing onward propagation: 0:00:00.004023 (0.36%)
# Wall time computing gradient: 0:00:00.059996 (5.31%)
#
# **** Iterations and function calls ****
# Number of iterations: 6
# Number of fidelity function calls: 8
# Number of times fidelity is computed: 8
# Number of gradient function calls: 8
# Number of times gradients are computed: 8
# Number of times timeslot evolution is recomputed: 8
#
# **** Control amplitudes ****
# Number of control amplitude updates: 7
# Mean number of updates per iteration: 1.1666666666666667
# Number of timeslot values changed: 2240
# Mean number of timeslot changes per update: 320.0
# Number of amplitude values changed: 4480
# Mean number of amplitude changes per update: 640.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 3.76860917e-06-1.01400162e-06j -2.85663008e-06+1.00000000e+00j]
#  [ 2.85663008e-06+1.00000000e+00j  3.76860916e-06+1.01400162e-06j]]
#
# ********* Summary *****************
# Final fidelity error 1.1751377648749894e-11
# Final gradient normal 7.885332675516492e-06
# Terminated due to function converged
# Number of iterations 6
# Completed in 0:00:01.129080 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=106.66666666666666
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:01.731281
# Wall time computing Hamiltonians: 0:00:00.055443 (3.20%)
# Wall time computing propagators: 0:00:01.344451 (77.66%)
# Wall time computing forward propagation: 0:00:00.007758 (0.45%)
# Wall time computing onward propagation: 0:00:00.007113 (0.41%)
# Wall time computing gradient: 0:00:00.098556 (5.69%)
#
# **** Iterations and function calls ****
# Number of iterations: 6
# Number of fidelity function calls: 9
# Number of times fidelity is computed: 9
# Number of gradient function calls: 9
# Number of times gradients are computed: 9
# Number of times timeslot evolution is recomputed: 9
#
# **** Control amplitudes ****
# Number of control amplitude updates: 8
# Mean number of updates per iteration: 1.3333333333333333
# Number of timeslot values changed: 3840
# Mean number of timeslot changes per update: 480.0
# Number of amplitude values changed: 7680
# Mean number of amplitude changes per update: 960.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 1.14205766e-06+4.50859040e-07j  1.19974931e-06+1.00000000e+00j]
#  [-1.19974931e-06+1.00000000e+00j  1.14205766e-06-4.50859041e-07j]]
#
# ********* Summary *****************
# Final fidelity error 1.56008539420327e-12
# Final gradient normal 3.3022905994189696e-06
# Terminated due to function converged
# Number of iterations 6
# Completed in 0:00:01.731281 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=142.22222222222223
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:02.659941
# Wall time computing Hamiltonians: 0:00:00.088651 (3.33%)
# Wall time computing propagators: 0:00:02.107741 (79.24%)
# Wall time computing forward propagation: 0:00:00.013935 (0.52%)
# Wall time computing onward propagation: 0:00:00.012730 (0.48%)
# Wall time computing gradient: 0:00:00.170513 (6.41%)
#
# **** Iterations and function calls ****
# Number of iterations: 10
# Number of fidelity function calls: 13
# Number of times fidelity is computed: 13
# Number of gradient function calls: 13
# Number of times gradients are computed: 13
# Number of times timeslot evolution is recomputed: 13
#
# **** Control amplitudes ****
# Number of control amplitude updates: 12
# Mean number of updates per iteration: 1.2
# Number of timeslot values changed: 6602
# Mean number of timeslot changes per update: 550.1666666666666
# Number of amplitude values changed: 9352
# Mean number of amplitude changes per update: 779.3333333333334
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 8.47330602e-06+2.24353675e-06j  5.92105657e-06+1.00000000e+00j]
#  [-5.92105657e-06+1.00000000e+00j  8.47330601e-06-2.24353674e-06j]]
#
# ********* Summary *****************
# Final fidelity error 5.6054383357206916e-11
# Final gradient normal 2.3090160422263168e-05
# Terminated due to function converged
# Number of iterations 10
# Completed in 0:00:02.659941 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=177.77777777777777
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:02.125632
# Wall time computing Hamiltonians: 0:00:00.075057 (3.53%)
# Wall time computing propagators: 0:00:01.601503 (75.34%)
# Wall time computing forward propagation: 0:00:00.011946 (0.56%)
# Wall time computing onward propagation: 0:00:00.011183 (0.53%)
# Wall time computing gradient: 0:00:00.158356 (7.45%)
#
# **** Iterations and function calls ****
# Number of iterations: 6
# Number of fidelity function calls: 9
# Number of times fidelity is computed: 9
# Number of gradient function calls: 9
# Number of times gradients are computed: 9
# Number of times timeslot evolution is recomputed: 9
#
# **** Control amplitudes ****
# Number of control amplitude updates: 8
# Mean number of updates per iteration: 1.3333333333333333
# Number of timeslot values changed: 6400
# Mean number of timeslot changes per update: 800.0
# Number of amplitude values changed: 12800
# Mean number of amplitude changes per update: 1600.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[-4.36060216e-11+2.85096820e-10j -5.45738229e-11+1.00000000e+00j]
#  [ 5.45750277e-11+1.00000000e+00j -4.36127662e-11-2.85099129e-10j]]
#
# ********* Summary *****************
# Final fidelity error 1.5210055437364645e-13
# Final gradient normal 6.953699255340306e-10
# Terminated due to function converged
# Number of iterations 6
# Completed in 0:00:02.125632 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=213.33333333333331
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:02.788378
# Wall time computing Hamiltonians: 0:00:00.105135 (3.77%)
# Wall time computing propagators: 0:00:02.117064 (75.92%)
# Wall time computing forward propagation: 0:00:00.015899 (0.57%)
# Wall time computing onward propagation: 0:00:00.014686 (0.53%)
# Wall time computing gradient: 0:00:00.198985 (7.14%)
#
# **** Iterations and function calls ****
# Number of iterations: 6
# Number of fidelity function calls: 10
# Number of times fidelity is computed: 10
# Number of gradient function calls: 10
# Number of times gradients are computed: 10
# Number of times timeslot evolution is recomputed: 10
#
# **** Control amplitudes ****
# Number of control amplitude updates: 9
# Mean number of updates per iteration: 1.5
# Number of timeslot values changed: 8640
# Mean number of timeslot changes per update: 960.0
# Number of amplitude values changed: 17280
# Mean number of amplitude changes per update: 1920.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[-1.43776988e-07-1.16300936e-06j  1.01734470e-07+1.00000000e+00j]
#  [-1.01734468e-07+1.00000000e+00j -1.43776992e-07+1.16300936e-06j]]
#
# ********* Summary *****************
# Final fidelity error 8.617551117140465e-13
# Final gradient normal 2.9535236282142357e-06
# Terminated due to function converged
# Number of iterations 6
# Completed in 0:00:02.788378 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=248.88888888888889
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:04.035937
# Wall time computing Hamiltonians: 0:00:00.142484 (3.53%)
# Wall time computing propagators: 0:00:03.177217 (78.72%)
# Wall time computing forward propagation: 0:00:00.020930 (0.52%)
# Wall time computing onward propagation: 0:00:00.019999 (0.50%)
# Wall time computing gradient: 0:00:00.279374 (6.92%)
#
# **** Iterations and function calls ****
# Number of iterations: 8
# Number of fidelity function calls: 12
# Number of times fidelity is computed: 12
# Number of gradient function calls: 12
# Number of times gradients are computed: 12
# Number of times timeslot evolution is recomputed: 12
#
# **** Control amplitudes ****
# Number of control amplitude updates: 11
# Mean number of updates per iteration: 1.375
# Number of timeslot values changed: 12320
# Mean number of timeslot changes per update: 1120.0
# Number of amplitude values changed: 24640
# Mean number of amplitude changes per update: 2240.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[-1.39807308e-07-3.82267224e-08j -7.67551873e-08-1.00000000e+00j]
#  [ 7.67551886e-08-1.00000000e+00j -1.39807319e-07+3.82267230e-08j]]
#
# ********* Summary *****************
# Final fidelity error 2.141620214501927e-13
# Final gradient normal 5.534005678134116e-07
# Terminated due to function converged
# Number of iterations 8
# Completed in 0:00:04.035937 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=284.44444444444446
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:04.481690
# Wall time computing Hamiltonians: 0:00:00.159464 (3.56%)
# Wall time computing propagators: 0:00:03.539932 (78.99%)
# Wall time computing forward propagation: 0:00:00.024241 (0.54%)
# Wall time computing onward propagation: 0:00:00.023832 (0.53%)
# Wall time computing gradient: 0:00:00.319400 (7.13%)
#
# **** Iterations and function calls ****
# Number of iterations: 9
# Number of fidelity function calls: 12
# Number of times fidelity is computed: 12
# Number of gradient function calls: 12
# Number of times gradients are computed: 12
# Number of times timeslot evolution is recomputed: 12
#
# **** Control amplitudes ****
# Number of control amplitude updates: 11
# Mean number of updates per iteration: 1.2222222222222223
# Number of timeslot values changed: 12408
# Mean number of timeslot changes per update: 1128.0
# Number of amplitude values changed: 17493
# Mean number of amplitude changes per update: 1590.2727272727273
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 3.12214210e-08+3.04532114e-07j  2.32000893e-07+1.00000000e+00j]
#  [-2.32000893e-07+1.00000000e+00j  3.12214273e-08-3.04532100e-07j]]
#
# ********* Summary *****************
# Final fidelity error 3.084199562408685e-13
# Final gradient normal 1.2523845463217066e-06
# Terminated due to function converged
# Number of iterations 9
# Completed in 0:00:04.481690 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=320.0
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:04.051207
# Wall time computing Hamiltonians: 0:00:00.152141 (3.76%)
# Wall time computing propagators: 0:00:03.124085 (77.11%)
# Wall time computing forward propagation: 0:00:00.023189 (0.57%)
# Wall time computing onward propagation: 0:00:00.022498 (0.56%)
# Wall time computing gradient: 0:00:00.300840 (7.43%)
#
# **** Iterations and function calls ****
# Number of iterations: 7
# Number of fidelity function calls: 10
# Number of times fidelity is computed: 10
# Number of gradient function calls: 10
# Number of times gradients are computed: 10
# Number of times timeslot evolution is recomputed: 10
#
# **** Control amplitudes ****
# Number of control amplitude updates: 9
# Mean number of updates per iteration: 1.2857142857142858
# Number of timeslot values changed: 12960
# Mean number of timeslot changes per update: 1440.0
# Number of amplitude values changed: 25920
# Mean number of amplitude changes per update: 2880.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 2.00967930e-10+2.09536479e-09j  1.36150194e-09+1.00000000e+00j]
#  [-1.36150132e-09+1.00000000e+00j  2.00961400e-10-2.09536372e-09j]]
#
# ********* Summary *****************
# Final fidelity error 2.4447111002245947e-13
# Final gradient normal 8.548658926199354e-09
# Terminated due to function converged
# Number of iterations 7
# Completed in 0:00:04.051207 HH:MM:SS.US

# %% [markdown]
# ### Optimise the pulse for each of the different evolution times

# %% [markdown]
# Here a loop is used to perform the optimisation for each of the evo_times given in the list above. The first optimisation is completed using the timeslot parameters passed when the optimisation objects are created. For the subsequent runs, the Dynamics object 'dyn' is used to set the timeslot parameters before the initial pulses are generated and optimisation is completed. Note that using this method, the dyn.initialize_controls method must be called with an array of the initial amplitudes before the optim.run_optimization method is called.

# %%
evo = results[9].evo_full_final
evo.tidyup(1e-3)
# len(H_c)
# H_c[4]
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[0.+0.j 0.-1.j]
#  [0.-1.j 0.+0.j]]

# %%
U_targ
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0. 1.]
#  [1. 0.]]

# %% [markdown]
# ### Plot the initial and final amplitudes

# %%
plot_results(n_evo_times,n_ctrls,results, evo_times)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Versions

# %%
pulse_seq = results[0].final_amps
U_targ
run_qutip_sim(subsystem_list,backend,results[4].final_amps,H_c,H_d).states[-1]
# Out:
# The Evolution element went wrong was
#  {'qobj': Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0.         0.49771143]
#  [0.49771143 0.        ]], 'targets': [0], 'tlist': array([ 0.        ,  0.22222222,  0.44444444,  0.66666667,  0.88888889,
#         1.11111111,  1.33333333,  1.55555556,  1.77777778,  2.        ,
#         2.22222222,  2.44444444,  2.66666667,  2.88888889,  3.11111111,
#         3.33333333,  3.55555556,  3.77777778,  4.        ,  4.22222222,
#         4.44444444,  4.66666667,  4.88888889,  5.11111111,  5.33333333,
#         5.55555556,  5.77777778,  6.        ,  6.22222222,  6.44444444,
#         6.66666667,  6.88888889,  7.11111111,  7.33333333,  7.55555556,
#         7.77777778,  8.        ,  8.22222222,  8.44444444,  8.66666667,
#         8.88888889,  9.11111111,  9.33333333,  9.55555556,  9.77777778,
#        10.        , 10.22222222, 10.44444444, 10.66666667, 10.88888889,
#        11.11111111, 11.33333333, 11.55555556, 11.77777778, 12.        ,
#        12.22222222, 12.44444444, 12.66666667, 12.88888889, 13.11111111,
#        13.33333333, 13.55555556, 13.77777778, 14.        , 14.22222222,
#        14.44444444, 14.66666667, 14.88888889, 15.11111111, 15.33333333,
#        15.55555556, 15.77777778, 16.        , 16.22222222, 16.44444444,
#        16.66666667, 16.88888889, 17.11111111, 17.33333333, 17.55555556,
#        17.77777778, 18.        , 18.22222222, 18.44444444, 18.66666667,
#        18.88888889, 19.11111111, 19.33333333, 19.55555556, 19.77777778,
#        20.        , 20.22222222, 20.44444444, 20.66666667, 20.88888889,
#        21.11111111, 21.33333333, 21.55555556, 21.77777778, 22.        ,
#        22.22222222, 22.44444444, 22.66666667, 22.88888889, 23.11111111,
#        23.33333333, 23.55555556, 23.77777778, 24.        , 24.22222222,
#        24.44444444, 24.66666667, 24.88888889, 25.11111111, 25.33333333,
#        25.55555556, 25.77777778, 26.        , 26.22222222, 26.44444444,
#        26.66666667, 26.88888889, 27.11111111, 27.33333333, 27.55555556,
#        27.77777778, 28.        , 28.22222222, 28.44444444, 28.66666667,
#        28.88888889, 29.11111111, 29.33333333, 29.55555556, 29.77777778,
#        30.        , 30.22222222, 30.44444444, 30.66666667, 30.88888889,
#        31.11111111, 31.33333333, 31.55555556, 31.77777778, 32.        ,
#        32.22222222, 32.44444444, 32.66666667, 32.88888889, 33.11111111,
#        33.33333333, 33.55555556, 33.77777778, 34.        , 34.22222222,
#        34.44444444, 34.66666667, 34.88888889, 35.11111111, 35.33333333,
#        35.55555556, 35.77777778, 36.        , 36.22222222, 36.44444444,
#        36.66666667, 36.88888889, 37.11111111, 37.33333333, 37.55555556,
#        37.77777778, 38.        , 38.22222222, 38.44444444, 38.66666667,
#        38.88888889, 39.11111111, 39.33333333, 39.55555556, 39.77777778,
#        40.        , 40.22222222, 40.44444444, 40.66666667, 40.88888889,
#        41.11111111, 41.33333333, 41.55555556, 41.77777778, 42.        ,
#        42.22222222, 42.44444444, 42.66666667, 42.88888889, 43.11111111,
#        43.33333333, 43.55555556, 43.77777778, 44.        , 44.22222222,
#        44.44444444, 44.66666667, 44.88888889, 45.11111111, 45.33333333,
#        45.55555556, 45.77777778, 46.        , 46.22222222, 46.44444444,
#        46.66666667, 46.88888889, 47.11111111, 47.33333333, 47.55555556,
#        47.77777778, 48.        , 48.22222222, 48.44444444, 48.66666667,
#        48.88888889, 49.11111111, 49.33333333, 49.55555556, 49.77777778,
#        50.        , 50.22222222, 50.44444444, 50.66666667, 50.88888889,
#        51.11111111, 51.33333333, 51.55555556, 51.77777778, 52.        ,
#        52.22222222, 52.44444444, 52.66666667, 52.88888889, 53.11111111,
#        53.33333333, 53.55555556, 53.77777778, 54.        , 54.22222222,
#        54.44444444, 54.66666667, 54.88888889, 55.11111111, 55.33333333,
#        55.55555556, 55.77777778, 56.        , 56.22222222, 56.44444444,
#        56.66666667, 56.88888889, 57.11111111, 57.33333333, 57.55555556,
#        57.77777778, 58.        , 58.22222222, 58.44444444, 58.66666667,
#        58.88888889, 59.11111111, 59.33333333, 59.55555556, 59.77777778,
#        60.        , 60.22222222, 60.44444444, 60.66666667, 60.88888889,
#        61.11111111, 61.33333333, 61.55555556, 61.77777778, 62.        ,
#        62.22222222, 62.44444444, 62.66666667, 62.88888889, 63.11111111,
#        63.33333333, 63.55555556, 63.77777778, 64.        , 64.22222222,
#        64.44444444, 64.66666667, 64.88888889, 65.11111111, 65.33333333,
#        65.55555556, 65.77777778, 66.        , 66.22222222, 66.44444444,
#        66.66666667, 66.88888889, 67.11111111, 67.33333333, 67.55555556,
#        67.77777778, 68.        , 68.22222222, 68.44444444, 68.66666667,
#        68.88888889, 69.11111111, 69.33333333, 69.55555556, 69.77777778,
#        70.        , 70.22222222, 70.44444444, 70.66666667, 70.88888889,
#        71.11111111]), 'coeff': [0.444406292369626, 0.44324626180767196, 0.4427435362895378, 0.44282488940901443, 0.4434057614564698, 0.4443928853285402, 0.44568694098028677, 0.4471851628931134, 0.4487838370246676, 0.4503806361373047, 0.45187675444149633, 0.45317881354275963, 0.4542005213815011, 0.45486407404791745, 0.45510129704593877, 0.4548545278931745, 0.45407724606869154, 0.4527344594785941, 0.45080285902453626, 0.4482707547393011, 0.4451378084742333, 0.44141457942714, 0.4371218999876422, 0.4322901005097481, 0.42695810271823625, 0.42117240249940513, 0.41498596377118874, 0.4084570459050506, 0.40164798770467747, 0.3946239711571995, 0.38745178799499225, 0.3801986314919907, 0.37293093484331014, 0.3657132759416634, 0.35860736639419605, 0.3516711402664327, 0.3449579553614121, 0.33851591692037797, 0.3323873305539348, 0.32660828807123954, 0.3212083867623623, 0.31621057969575284, 0.31163115180368156, 0.30747981402004804, 0.30375990557229915, 0.3004686927636792, 0.2975977512488096, 0.29513341792205866, 0.29305729810326747, 0.29134681370006804, 0.2899757784147251, 0.2889149867968084, 0.28813280496136245, 0.2875957520296399, 0.28726906273777764, 0.2871172231317825, 0.28710447276380474, 0.2871952682717327, 0.2873547046180214, 0.28754889155109037, 0.2877452840106253, 0.28791296621329515, 0.28802289002265646, 0.2880480689281177, 0.2879637295396769, 0.287747422958261, 0.28737909871859035, 0.28684114423633833, 0.28611839283780105, 0.28519810352168984, 0.28406991561139966, 0.2827257814134228, 0.28115987991344216, 0.27936851442479876, 0.27734999696206497, 0.2751045219518965, 0.27263403171976147, 0.26994207600931114, 0.2670336676050303, 0.2639151359417565, 0.2605939803993805, 0.25707872479976723, 0.253378774447373, 0.2495042768864887, 0.24546598738745634, 0.24127514002221606, 0.23694332504651794, 0.23248237317227122, 0.2279042471888198, 0.22322094127636016, 0.21844438824810325, 0.21358637485994292, 0.2086584652371098, 0.20367193238636194, 0.19863769768945197, 0.1935662782087214, 0.18846774157846807, 0.1833516682060069, 0.17822712046383712, 0.17310261851881428, 0.16798612241538904, 0.16288502000754107, 0.15780612031764182, 0.15275565188977222, 0.1477392656995994, 0.14276204218236163, 0.1378285019443781, 0.13294261973135157, 0.12810784123808586, 0.12332710235865624, 0.1186028504930793, 0.11393706754569397, 0.10933129427135516, 0.10478665564775506, 0.10030388697534108, 0.09588336043004074, 0.09152511181801717, 0.08722886730566293, 0.08299406992174996, 0.07881990565184839, 0.07470532896762785, 0.07064908765528143, 0.06664974682794378, 0.06270571202649088, 0.05881525133143694, 0.054976516425714904, 0.05118756256391392, 0.04744636741801904, 0.04375084878286546, 0.040098881136383165, 0.03648831106030636, 0.03291697153637753, 0.02938269514125073, 0.025883326170330696, 0.02241673172674385, 0.01898081181658046, 0.015573508495546446, 0.012192814115276595, 0.008836778719871985, 0.005503516644783582, 0.002191212371055018, -0.001101874311788732, -0.004377403781186972, -0.007636952643066761, -0.010882010328373073, -0.014113976175107026, -0.017334156948268183, -0.020543764752280053, -0.023743915292900444, -0.02693562644824838, -0.030119817111377126, -0.033297306269767554, -0.0364688122901696, -0.03963495238037268, -0.04279624220270516, -0.04595309561734573, -0.049105824536847316, -0.05225463887663143, -0.05539964658958133, -0.05854085377625538, -0.06167816486563684, -0.06481138286474022, -0.0679402096787947, -0.07106424650712422, -0.07418299432323637, -0.07729585445101612, -0.08040212925229179, -0.08350102294439266, -0.08659164256965156, -0.08967299914210865, -0.09274400899993371, -0.09580349539530195, -0.09885019035660877, -0.10188273686097954, -0.10489969135799977, -0.10789952668843557, -0.11088063544440367, -0.11384133381995062, -0.11677986600327192, -0.11969440916380421, -0.12258307908909699, -0.12544393652766883, -0.12827499429489725, -0.13107422519932957, -0.13383957084653622, -0.1365689513766877, -0.13926027619031742, -0.1419114557141451, -0.144520414 ...
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-07b09522102e> in <module>
#       1 pulse_seq = results[0].final_amps
#       2 U_targ
# ----> 3 run_qutip_sim(subsystem_list,backend,results[4].final_amps,H_c,H_d).states[-1]
#
# ~/oct-qiskit-pulse/src/three_restructure.py in run_qutip_sim(subsystem_list, backend, pulse_seq, H_c, H_d, def_seq, init_state)
#     219     basis0 = basis(3 ** len(subsystem_list), init_state)
#     220     # basis0 = basis(4,0) + basis(4,2)
# --> 221     result = processor.run_state(init_state=basis0)
#     222
#     223     result.states[-1].tidyup(1.e-3)
#
# ~/anaconda3/envs/qoc/lib/python3.8/site-packages/qutip/qip/device/processor.py in run_state(self, init_state, analytical, states, noisy, **kwargs)
#     679                     args=kwargs["args"], noisy=noisy)
#     680         else:
# --> 681             noisy_qobjevo, sys_c_ops = self.get_qobjevo(noisy=noisy)
#     682
#     683         # add collpase operators into kwargs
#
# ~/anaconda3/envs/qoc/lib/python3.8/site-packages/qutip/qip/device/processor.py in get_qobjevo(self, args, noisy)
#     536         for pulse in dynamics:
#     537             if noisy:
# --> 538                 qu, new_c_ops = pulse.get_noisy_qobjevo(dims=self.dims)
#     539                 c_ops += new_c_ops
#     540             else:
#
# ~/anaconda3/envs/qoc/lib/python3.8/site-packages/qutip/qip/pulse.py in get_noisy_qobjevo(self, dims)
#     387             A list of (time-dependent) lindbald operators.
#     388         """
# --> 389         ideal_qu = self.get_ideal_qobjevo(dims)
#     390         noise_qu_list = [noise.get_qobjevo(self.spline_kind, dims)
#     391                          for noise in self.coherent_noise]
#
# ~/anaconda3/envs/qoc/lib/python3.8/site-packages/qutip/qip/pulse.py in get_ideal_qobjevo(self, dims)
#     366             A `QobjEvo` representing the ideal evolution.
#     367         """
# --> 368         return self.ideal_pulse.get_qobjevo(self.spline_kind, dims)
#     369
#     370     def get_noisy_qobjevo(self, dims):
#
# ~/anaconda3/envs/qoc/lib/python3.8/site-packages/qutip/qip/pulse.py in get_qobjevo(self, spline_kind, dims)
#     123             print(
#     124                 "The Evolution element went wrong was\n {}".format(str(self)))
# --> 125             raise(err)
#     126
#     127     def __str__(self):
#
# ~/anaconda3/envs/qoc/lib/python3.8/site-packages/qutip/qip/pulse.py in get_qobjevo(self, spline_kind, dims)
#     119         """
#     120         try:
# --> 121             return self._get_qobjevo_helper(spline_kind, dims=dims)
#     122         except Exception as err:
#     123             print(
#
# ~/anaconda3/envs/qoc/lib/python3.8/site-packages/qutip/qip/pulse.py in _get_qobjevo_helper(self, spline_kind, dims)
#      60         Please refer to `_Evoelement.get_qobjevo` for documentation.
#      61         """
# ---> 62         mat = self.get_qobj(dims)
#      63         if self.tlist is None and self.coeff is None:
#      64             qu = QobjEvo(mat) * 0.
#
# ~/anaconda3/envs/qoc/lib/python3.8/site-packages/qutip/qip/pulse.py in get_qobj(self, dims)
#      54             qobj = self.qobj
#      55             targets = self.targets
# ---> 56         return expand_operator(qobj, len(dims), targets, dims)
#      57
#      58     def _get_qobjevo_helper(self, spline_kind, dims):
#
# ~/anaconda3/envs/qoc/lib/python3.8/site-packages/qutip/qip/operations/gates.py in expand_operator(oper, N, targets, dims, cyclic_permutation)
#    1225         dims = [2] * N
#    1226     targets = _targets_to_list(targets, oper=oper, N=N)
# -> 1227     _check_qubits_oper(oper, dims=dims, targets=targets)
#    1228
#    1229     # Call expand_operator for all cyclic permutation of the targets.
#
# ~/anaconda3/envs/qoc/lib/python3.8/site-packages/qutip/qip/operations/gates.py in _check_qubits_oper(oper, dims, targets)
#    1140         targ_dims = [dims[t] for t in targets]
#    1141         if oper.dims[0] != targ_dims:
# -> 1142             raise ValueError(
#    1143                 "The operator dims {} do not match "
#    1144                 "the target dims {}.".format(
#
# ValueError: The operator dims [2] do not match the target dims [3].

# %% [markdown]
# ### Run QuTip pulse simulation

# %%
# init_x = backend.defaults().instruction_schedule_map.get('x',[0])
# init_x
# run_qutip_sim(subsystem_list, backend, pulse_seq, H_c, H_d)
# def_seq = init_x.instructions[0]
# def_seq=def_seq[1].pulse.get_waveform().samples
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# results[0].final_amps
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Create Channels and convert qoc pulses to Qiskit pulses

# %%
# Create the base schedule

# schedule = def_cx
# schedule.draw(plot_range=[0, 1000])
qoc_programs = [generate_qiskit_program(result.final_amps, backend, derotate_flag=DEROTATE) for result in results]
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Run the assembled pulse schedule

# %%
jobs = []
for i,program in enumerate(qoc_programs):
    cur_job = backend.run(program)
    jobs.append(cur_job)
    pulse_steps = n_ts_list[i]
    cur_job.update_tags(['QOC', 'n_ts=' + str(pulse_steps), p_type])

# jobs.append(def_job)
# job = backend.run(frequency_sweep_program)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
U_targ
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0. 1.]
#  [1. 0.]]

# %%
# def_job=backend.run(generate_qiskit_program(def_seq,backend, True))
# def_job.update_tags(['builtin'])
from src.helper import qubit_distribution
qubit_distribution(jobs[0].result().get_counts())
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {0: {0: 990, 1: 34},
#  1: {0: 1013, 1: 11},
#  2: {0: 1015, 1: 9},
#  3: {0: 1013, 1: 11},
#  4: {0: 107, 1: 917}}

# %%
# job_monitor(jobs[0])
from qiskit.tools.monitor import job_monitor
job_monitor(jobs[-1])
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Job Status: job has successfully run

# %%
last_qub = backend.configuration().n_qubits

acc = {a:0 for a in n_ts_list}
for i,job in enumerate(jobs):
    n_ts = n_ts_list[i]
    cur_acc = qubit_distribution(job.result().get_counts())[last_qub-1][1]/1024
    acc[n_ts] = cur_acc
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
acc
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {64: 0.8955078125,
#  96: 0.9013671875,
#  128: 0.8583984375,
#  160: 0.828125,
#  320: 0.83203125,
#  480: 0.7216796875,
#  640: 0.7177734375,
#  800: 0.494140625,
#  960: 0.607421875,
#  1120: 0.5478515625,
#  1280: 0.4931640625,
#  1440: 0.3837890625}

# %%
# f_csv='results.csv'
# write_results(f_csv, acc, p_type, backend, 'X')
# notes = '2 levels, first section cnot 1-0 qubit 0'
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# gate_type = 'hadamrd'
# notes = 'no y control'
# notes = ''
if DEROTATE:
    notes+= 'derotated'
# f = open(f_csv,'wb')
# acc['p_type'] = p_type
# acc['backend'] = backend.name()
# acc['gate_type'/] = gate_type
# w = csv.DictWriter(f,acc.keys())
# w.writerow(acc)
# f.close()
notes += ', not_packaged'
import csv
# notes = '2 levels'

with open('results.csv', 'a', newline='') as csvfile:
    # fieldnames = ['n_ts', 'frac_1', 'p_type', 'backend', 'gate_type', 'delta0', 'creation_date', 'notes']
     fieldnames = ['n_ts', 'frac_1', 'p_type', 'backend',
                          'gate_type', 'two_lvl', 'delta0', 'creation_date', 'notes']
        
     writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    # writer.writeheader() 
     for i,row in enumerate(acc.keys()):
        out_dict = {'n_ts': row, 'frac_1' : acc[row], 'p_type': p_type, 'backend' : backend.name(),
                    'gate_type' : gate_type, 'two_lvl': two_level, 'delta0' : backend.configuration().hamiltonian['vars']['delta0'], 'creation_date' : jobs[i].creation_date(), 'notes' : notes}
        writer.writerow(out_dict)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
jobs[0].result()
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from qiskit.circuit.library import HGate, U2Gate
import qiskit
circ = qiskit.QuantumCircuit(1,1)
circ.h(0)
transp_circ = qiskit.transpile(circ, backend=backend)
transp_circ.data[0]
# backend.defaults().instruction_schedule_map.get(U2Gate())
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (<qiskit.circuit.library.standard_gates.u2.U2Gate at 0x7f98361b04c0>,
#  [Qubit(QuantumRegister(5, 'q'), 0)],
#  [])

# %%
# defh = backend.defaults().instruction_schedule_map.get()


# def_seq = defh.instructions[0]
# def_seq=def_seq[1].pulse.get_waveform().samples
# run_qutip_sim(subsystem_list, backend, pulse_seq, H_c, H_d,def_seq=def_seq)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
