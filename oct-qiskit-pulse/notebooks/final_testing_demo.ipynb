# %% [markdown]
# # Testing of QuTiP QOC on Qiskit using IBM backend

# %% [markdown]
# Ben Rosand (brosand@gmail.com)

# %% [markdown]
# ### Imports

# %%
from src.QOCTester import QOCTester
from qiskit import IBMQ
from qiskit.tools.monitor import job_monitor
import numpy as np

# %%
IBMQ.load_account()

provider = IBMQ.get_provider(hub='ibm-q-internal', group='deployed', project='default')
backend = provider.get_backend('ibmq_valencia')
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
target_name = 'XGate'
subsystem_list = [0]

config = backend.configuration()

tester = QOCTester(config, subsystem_list, p_type='LIN', two_level=True)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# tester.make_two_level()
tester.init_unitaries(target_name)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
n_ts_list=np.arange(64,320,64)
tester.time_init(n_ts_list=n_ts_list)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
optim = tester.create_pulse_optimizer()
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
results = tester.tester_run_optimizer(optim)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Internal operator data type choosen to be <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=14.222222222222221
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:00.235497
# Wall time computing Hamiltonians: 0:00:00.008283 (3.52%)
# Wall time computing propagators: 0:00:00.180710 (76.74%)
# Wall time computing forward propagation: 0:00:00.001124 (0.48%)
# Wall time computing onward propagation: 0:00:00.001080 (0.46%)
# Wall time computing gradient: 0:00:00.014824 (6.29%)
#
# **** Iterations and function calls ****
# Number of iterations: 10
# Number of fidelity function calls: 12
# Number of times fidelity is computed: 12
# Number of gradient function calls: 12
# Number of times gradients are computed: 12
# Number of times timeslot evolution is recomputed: 12
#
# **** Control amplitudes ****
# Number of control amplitude updates: 11
# Mean number of updates per iteration: 1.1
# Number of timeslot values changed: 704
# Mean number of timeslot changes per update: 64.0
# Number of amplitude values changed: 832
# Mean number of amplitude changes per update: 75.63636363636364
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 9.34705186e-01-2.15170048e-05j  7.17746762e-05+3.55423986e-01j]
#  [-7.17746762e-05+3.55423986e-01j  9.34705186e-01+2.15170048e-05j]]
#
# ********* Summary *****************
# Final fidelity error 0.6445760140548751
# Final gradient normal 0.06065028771050101
# Terminated due to function converged
# Number of iterations 10
# Completed in 0:00:00.235497 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=28.444444444444443
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:00.405363
# Wall time computing Hamiltonians: 0:00:00.016365 (4.04%)
# Wall time computing propagators: 0:00:00.299858 (73.97%)
# Wall time computing forward propagation: 0:00:00.002469 (0.61%)
# Wall time computing onward propagation: 0:00:00.002084 (0.51%)
# Wall time computing gradient: 0:00:00.031788 (7.84%)
#
# **** Iterations and function calls ****
# Number of iterations: 11
# Number of fidelity function calls: 12
# Number of times fidelity is computed: 12
# Number of gradient function calls: 12
# Number of times gradients are computed: 12
# Number of times timeslot evolution is recomputed: 12
#
# **** Control amplitudes ****
# Number of control amplitude updates: 11
# Mean number of updates per iteration: 1.0
# Number of timeslot values changed: 1408
# Mean number of timeslot changes per update: 128.0
# Number of amplitude values changed: 1697
# Mean number of amplitude changes per update: 154.27272727272728
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 7.47347560e-01+6.17878906e-05j -3.30341118e-04-6.64433226e-01j]
#  [ 3.30341118e-04-6.64433226e-01j  7.47347560e-01-6.17878906e-05j]]
#
# ********* Summary *****************
# Final fidelity error 0.3355667736928758
# Final gradient normal 0.06857973844078251
# Terminated due to function converged
# Number of iterations 11
# Completed in 0:00:00.405363 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=42.666666666666664
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:00.542594
# Wall time computing Hamiltonians: 0:00:00.025044 (4.62%)
# Wall time computing propagators: 0:00:00.391455 (72.15%)
# Wall time computing forward propagation: 0:00:00.003656 (0.67%)
# Wall time computing onward propagation: 0:00:00.003201 (0.59%)
# Wall time computing gradient: 0:00:00.049513 (9.13%)
#
# **** Iterations and function calls ****
# Number of iterations: 12
# Number of fidelity function calls: 13
# Number of times fidelity is computed: 13
# Number of gradient function calls: 13
# Number of times gradients are computed: 13
# Number of times timeslot evolution is recomputed: 13
#
# **** Control amplitudes ****
# Number of control amplitude updates: 12
# Mean number of updates per iteration: 1.0
# Number of timeslot values changed: 2304
# Mean number of timeslot changes per update: 192.0
# Number of amplitude values changed: 2789
# Mean number of amplitude changes per update: 232.41666666666666
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 4.62394001e-01+1.15084422e-05j -3.67472926e-04-8.86674491e-01j]
#  [ 3.67472926e-04-8.86674491e-01j  4.62394001e-01-1.15084422e-05j]]
#
# ********* Summary *****************
# Final fidelity error 0.11332550920938567
# Final gradient normal 0.051967420586629696
# Terminated due to function converged
# Number of iterations 12
# Completed in 0:00:00.542594 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=56.888888888888886
# +++++++++++++++++++++++++++++++++++
#
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:01.065172
# Wall time computing Hamiltonians: 0:00:00.044620 (4.19%)
# Wall time computing propagators: 0:00:00.814477 (76.46%)
# Wall time computing forward propagation: 0:00:00.006673 (0.63%)
# Wall time computing onward propagation: 0:00:00.006720 (0.63%)
# Wall time computing gradient: 0:00:00.088195 (8.28%)
#
# **** Iterations and function calls ****
# Number of iterations: 16
# Number of fidelity function calls: 17
# Number of times fidelity is computed: 17
# Number of gradient function calls: 17
# Number of times gradients are computed: 17
# Number of times timeslot evolution is recomputed: 17
#
# **** Control amplitudes ****
# Number of control amplitude updates: 16
# Mean number of updates per iteration: 1.0
# Number of timeslot values changed: 4096
# Mean number of timeslot changes per update: 256.0
# Number of amplitude values changed: 4775
# Mean number of amplitude changes per update: 298.4375
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 0.11705794-6.28079519e-05j -0.00016952-9.93125070e-01j]
#  [ 0.00016952-9.93125070e-01j  0.11705794+6.28079519e-05j]]
#
# ********* Summary *****************
# Final fidelity error 0.006874929895861248
# Final gradient normal 0.01519110020029458
# Terminated due to function converged
# Number of iterations 16
# Completed in 0:00:01.065172 HH:MM:SS.US

# %%
tester.plot_all_results(results)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
programs = tester.gen_qiskit_progs(results, backend)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
jobs = tester.run_qiskit_programs(programs,backend)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
job_monitor(jobs[-1])
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Job Status: job has successfully run

# %%
acc = tester.get_acc(jobs)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
acc
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {64: 0.103515625, 128: 0.2470703125, 192: 0.68359375, 256: 0.859375}

# %%
tester.write_acc(acc, 'results.csv')
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tester.H_c
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.         0.03649898]
#   [0.03649898 0.        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.+0.j         0.-0.03649898j]
#   [0.+0.03649898j 0.+0.j        ]]]

# %%
from src.three_restructure import generate_schedule
from qiskit.pulse import DriveChannel
sched = generate_schedule(results[0].final_amps, backend, draw_progs=True)
sched.draw(plot_range=[0,200], channels=[DriveChannel(0)])
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
