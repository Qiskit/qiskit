# %% [markdown]
# # Testing of QuTiP QOC on Qiskit using IBM backend

# %% [markdown]
# Ben Rosand (brosand@gmail.com)

# %% [markdown]
# ### Imports

# %%
from src.QOCTester import QOCTester
from qiskit import IBMQ
from qiskit.tools.monitor import job_monitor
import numpy as np

# %%
IBMQ.load_account()

provider = IBMQ.get_provider(hub='ibm-q-internal', group='deployed', project='default')
backend = provider.get_backend('ibmq_armonk')

# %%
target_name = 'XGate'
subsystem_list = [0]

config = backend.configuration()

tester = QOCTester(config, subsystem_list, p_type='LIN', two_level=True)
# Out:
# not using control channels, skippping...
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# tester.make_two_level()
tester.init_unitaries(target_name)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
n_ts_list=np.arange(64,320,64)
tester.time_init(n_ts_list=n_ts_list)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
optim = tester.create_pulse_optimizer()
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
results = tester.tester_run_optimizer(optim)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Internal operator data type choosen to be <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=14.222222222222221
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:00.195269
# Wall time computing Hamiltonians: 0:00:00.006359 (3.26%)
# Wall time computing propagators: 0:00:00.143477 (73.48%)
# Wall time computing forward propagation: 0:00:00.001192 (0.61%)
# Wall time computing onward propagation: 0:00:00.000765 (0.39%)
# Wall time computing gradient: 0:00:00.012633 (6.47%)
#
# **** Iterations and function calls ****
# Number of iterations: 7
# Number of fidelity function calls: 9
# Number of times fidelity is computed: 9
# Number of gradient function calls: 9
# Number of times gradients are computed: 9
# Number of times timeslot evolution is recomputed: 9
#
# **** Control amplitudes ****
# Number of control amplitude updates: 8
# Mean number of updates per iteration: 1.1428571428571428
# Number of timeslot values changed: 512
# Mean number of timeslot changes per update: 64.0
# Number of amplitude values changed: 1024
# Mean number of amplitude changes per update: 128.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[-1.54595076e-06-3.41539129e-06j -2.63815308e-08+1.00000000e+00j]
#  [ 2.63815303e-08+1.00000000e+00j -1.54595075e-06+3.41539130e-06j]]
#
# ********* Summary *****************
# Final fidelity error 7.0397021545431926e-12
# Final gradient normal 2.5439864628411926e-06
# Terminated due to function converged
# Number of iterations 7
# Completed in 0:00:00.195269 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=28.444444444444443
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:00.245919
# Wall time computing Hamiltonians: 0:00:00.012748 (5.18%)
# Wall time computing propagators: 0:00:00.168297 (68.44%)
# Wall time computing forward propagation: 0:00:00.001302 (0.53%)
# Wall time computing onward propagation: 0:00:00.001139 (0.46%)
# Wall time computing gradient: 0:00:00.017207 (7.00%)
#
# **** Iterations and function calls ****
# Number of iterations: 6
# Number of fidelity function calls: 7
# Number of times fidelity is computed: 7
# Number of gradient function calls: 7
# Number of times gradients are computed: 7
# Number of times timeslot evolution is recomputed: 7
#
# **** Control amplitudes ****
# Number of control amplitude updates: 6
# Mean number of updates per iteration: 1.0
# Number of timeslot values changed: 768
# Mean number of timeslot changes per update: 128.0
# Number of amplitude values changed: 1536
# Mean number of amplitude changes per update: 256.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[ 1.38043361e-05-1.28483430e-04j -2.59463159e-05-9.99999991e-01j]
#  [ 2.59463159e-05-9.99999991e-01j  1.38043361e-05+1.28483430e-04j]]
#
# ********* Summary *****************
# Final fidelity error 8.685899777205464e-09
# Final gradient normal 0.00013944289678354823
# Terminated due to function converged
# Number of iterations 6
# Completed in 0:00:00.245919 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=42.666666666666664
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:00.315875
# Wall time computing Hamiltonians: 0:00:00.012647 (4.00%)
# Wall time computing propagators: 0:00:00.214075 (67.77%)
# Wall time computing forward propagation: 0:00:00.002018 (0.64%)
# Wall time computing onward propagation: 0:00:00.001595 (0.50%)
# Wall time computing gradient: 0:00:00.022867 (7.24%)
#
# **** Iterations and function calls ****
# Number of iterations: 6
# Number of fidelity function calls: 7
# Number of times fidelity is computed: 7
# Number of gradient function calls: 7
# Number of times gradients are computed: 7
# Number of times timeslot evolution is recomputed: 7
#
# **** Control amplitudes ****
# Number of control amplitude updates: 6
# Mean number of updates per iteration: 1.0
# Number of timeslot values changed: 1152
# Mean number of timeslot changes per update: 192.0
# Number of amplitude values changed: 2304
# Mean number of amplitude changes per update: 384.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[-3.28637438e-07+3.84645096e-07j  6.18528463e-07-1.00000000e+00j]
#  [-6.18528464e-07-1.00000000e+00j -3.28637438e-07-3.84645096e-07j]]
#
# ********* Summary *****************
# Final fidelity error 3.544942117628125e-13
# Final gradient normal 9.855689777981525e-07
# Terminated due to function converged
# Number of iterations 6
# Completed in 0:00:00.315875 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=56.888888888888886
# +++++++++++++++++++++++++++++++++++
#
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:00.458409
# Wall time computing Hamiltonians: 0:00:00.017342 (3.78%)
# Wall time computing propagators: 0:00:00.316157 (68.97%)
# Wall time computing forward propagation: 0:00:00.003057 (0.67%)
# Wall time computing onward propagation: 0:00:00.002617 (0.57%)
# Wall time computing gradient: 0:00:00.035913 (7.83%)
#
# **** Iterations and function calls ****
# Number of iterations: 7
# Number of fidelity function calls: 8
# Number of times fidelity is computed: 8
# Number of gradient function calls: 8
# Number of times gradients are computed: 8
# Number of times timeslot evolution is recomputed: 8
#
# **** Control amplitudes ****
# Number of control amplitude updates: 7
# Mean number of updates per iteration: 1.0
# Number of timeslot values changed: 1792
# Mean number of timeslot changes per update: 256.0
# Number of amplitude values changed: 3584
# Mean number of amplitude changes per update: 512.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[-2.42564991e-07-9.01799044e-08j -5.88071977e-07-1.00000000e+00j]
#  [ 5.88071979e-07-1.00000000e+00j -2.42564987e-07+9.01799011e-08j]]
#
# ********* Summary *****************
# Final fidelity error 2.530198273120732e-13
# Final gradient normal 8.66256022848938e-07
# Terminated due to function converged
# Number of iterations 7
# Completed in 0:00:00.458409 HH:MM:SS.US

# %%
tester.plot_all_results(results)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
programs = tester.gen_qiskit_progs(results, backend)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
jobs = tester.run_qiskit_programs(programs,backend)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
job_monitor(jobs[-1])
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-affe73382d38> in <module>
# ----> 1 job_monitor(jobs[-1])
#
# NameError: name 'jobs' is not defined

# %%
acc = tester.get_acc(jobs)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0576be9be0f6> in <module>
# ----> 1 acc = tester.get_acc(jobs)
#
# NameError: name 'jobs' is not defined

# %%
acc
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0a304da0f193> in <module>
# ----> 1 acc
#
# NameError: name 'acc' is not defined

# %%
tester.write_acc(acc, 'results.csv')
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-21d1d80970f1> in <module>
# ----> 1 tester.write_acc(acc, 'results.csv')
#
# NameError: name 'acc' is not defined

# %%
from src.three_restructure import generate_schedule
from qiskit.pulse import DriveChannel
sched = generate_schedule(results[0].final_amps, backend, draw_progs=True)
sched.draw(plot_range=[0,200], channels=[DriveChannel(0)])
